# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("preprocessed_dataset/new_trade_df.csv")
trades_df = pd.DataFrame(data)
trades_df
# Out:
#                                         transaction_hash  transaction_index  \
# 0      0xd7697254e0c81b5495d33eb97f6df0b7712bed9f7240...                 30
# 1      0x79ce5fd00f68d7c01e968330b4fd1d18d4dab63da449...                354
# 2      0xd68434292eeb51fbcaaa5a7f123677b3e6c1860fa245...                191
# 3      0x13f54f315829585f277dd8370b669cf537c21c071051...                173
# 4      0xb1d1e3a952d904d6c1bf323538ec4c36d3cf3a0f3bb0...                127
# ...                                                  ...                ...
# 36179  0x4d6800bc7247754b3f71324c7631ec7065bfcdae2188...                 35
# 36180  0x18d5d225fa2164ec1b413f9e4771ef2ce2058c03c708...                 19
# 36181  0x1104e053a73a7ec5639a3cbafeab9a29933fe35f8c41...                 41
# 36182  0x9310dd9850a933182519bbc8dcc67635be78b0567ada...                 30
# 36183  0xea3424e625db10490e416dfa92411111685061281069...                 24
#
# ...

# %%
nft_df_1 = pd.read_csv("preprocessed_dataset/ntf_df1.csv")
nft_df_2 = pd.read_csv("preprocessed_dataset/ntf_df2.csv")
nft_df_3 = pd.read_csv("preprocessed_dataset/ntf_df3.csv")
nft_df_4 = pd.read_csv("preprocessed_dataset/ntf_df4.csv")
nft_df_5 = pd.read_csv("preprocessed_dataset/ntf_df5.csv")
nft_df = pd.concat([nft_df_1, nft_df_2, nft_df_3, nft_df_4, nft_df_5])
# Out:
# /var/folders/x2/q5931tb11yq9yxz816qjmy7w0000gn/T/ipykernel_2150/2649438829.py:2: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   nft_df_2 = pd.read_csv("preprocessed_dataset/ntf_df2.csv")

# %%
nft_df
# Out:
#        token_id                               token_address  amount  \
# 0             0  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 1             1  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 2             2  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 3             3  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 4             4  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# ...         ...                                         ...     ...
# 19934     99995  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 19935     99996  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 19936     99997  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 19937     99998  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 19938     99999  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
#
#                                          owner_of  \
# 0      0xf7801b8115f3fe46ac55f8c0fdb5243726bdb66a
# ...

# %%
nft_df_5.shape
# Out:
# (19939, 32)

# %%
nft_df.columns
# Out:
# Index(['token_id', 'token_address', 'amount', 'owner_of', 'token_hash',
#        'block_number_minted', 'block_number', 'transfer_index',
#        'contract_type', 'name', 'symbol', 'token_uri', 'metadata',
#        'last_token_uri_sync', 'last_metadata_sync', 'Artifact', 'Category',
#        'Eastern Resource', 'Eastern Resource Tier', 'Environment',
#        'Environment Tier', 'Koda', 'Northern Resource',
#        'Northern Resource Tier', 'Obelisk Piece', 'Plot', 'Sediment',
#        'Sediment Tier', 'Southern Resource', 'Southern Resource Tier',
#        'Western Resource', 'Western Resource Tier'],
#       dtype='object')

# %%
nft_df=nft_df.rename(columns={"token_id":"token_ids"})
nft_df
# Out:
#        token_ids                               token_address  amount  \
# 0              0  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 1              1  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 2              2  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 3              3  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 4              4  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# ...          ...                                         ...     ...
# 19934      99995  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 19935      99996  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 19936      99997  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 19937      99998  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
# 19938      99999  0x34d85c9cdeb23fa97cb08333b511ac86e1c4e258       1
#
#                                          owner_of  \
# 0      0xf7801b8115f3fe46ac55f8c0fdb5243726bdb66a
# ...

# %%
trades_df = trades_df[["token_ids","block_timestamp","price_usd"]]
trades_df
# Out:
#        token_ids block_timestamp     price_usd
# 0          23446      2022-09-17   2866.434466
# 1          11227      2022-09-17   2794.773604
# 2          17507      2022-09-16   3827.013750
# 3          77132      2022-09-16   2943.856731
# 4          54283      2022-09-16   2575.874639
# ...          ...             ...           ...
# 36179      49495      2022-05-01  21847.121991
# 36180      51155      2022-05-01  21847.121991
# 36181      45735      2022-05-01  22775.624676
# 36182      50763      2022-05-01  23212.567116
# 36183      46903      2022-05-01  24578.012240
#
# [36184 rows x 3 columns]

# %%
nft_df = nft_df[['token_ids', 'Artifact', 'Category',
       'Eastern Resource', 'Eastern Resource Tier', 'Environment',
       'Environment Tier', 'Koda', 'Northern Resource',
       'Northern Resource Tier', 'Obelisk Piece', 'Plot', 'Sediment',
       'Sediment Tier', 'Southern Resource', 'Southern Resource Tier',
       'Western Resource', 'Western Resource Tier']]

# %%
df = nft_df.merge(trades_df, on='token_ids', how='left')
df = df.dropna(subset=["price_usd"])
df
# Out:
#         token_ids       Artifact     Category Eastern Resource  \
# 9               9            NaN        Decay           Nether
# 10             10            NaN        Decay              NaN
# 12             12            NaN        Decay              NaN
# 16             16            NaN        Harsh          Whisper
# 17             17            NaN        Decay              NaN
# ...           ...            ...          ...              ...
# 108943      99996            NaN        Harsh              NaN
# 108944      99996            NaN        Harsh              NaN
# 108945      99996            NaN        Harsh              NaN
# 108947      99998            NaN  Psychedelic        Spikeweed
# 108948      99999  Rugged Hammer      Mineral              NaN
#
#         Eastern Resource Tier Environment  Environment Tier  Koda  \
# 9                         2.0   Thornwood                 2   NaN
# 10                        NaN       Ruins                 1   NaN
# ...

# %%
df = df.groupby("token_ids").first()
df
# Out:
#                 Artifact     Category Eastern Resource  Eastern Resource Tier  \
# token_ids
# 9                   None        Decay           Nether                    2.0
# 10                  None        Decay             None                    NaN
# 12                  None        Decay             None                    NaN
# 16                  None        Harsh          Whisper                    3.0
# 17                  None        Decay             None                    NaN
# ...                  ...          ...              ...                    ...
# 99990               None       Spirit       Psychosilk                    2.0
# 99994               None      Mineral             None                    NaN
# 99996               None        Harsh             None                    NaN
# 99998               None  Psychedelic        Spikeweed                    1.0
# 99999      Rugged Hammer      Mineral             None                    NaN
#
# ...

# %%
df.describe()
# Out:
#        Eastern Resource Tier  Environment Tier         Koda  \
# count           12139.000000      27171.000000  3076.000000
# mean                1.637697          2.491075  5017.348830
# std                 0.750053          1.317817  2913.919422
# min                 1.000000          1.000000     2.000000
# 25%                 1.000000          1.000000  2441.000000
# 50%                 1.000000          2.000000  5031.500000
# 75%                 2.000000          3.000000  7559.250000
# max                 3.000000          5.000000  9999.000000
#
#        Northern Resource Tier          Plot  Sediment Tier  \
# count            11996.000000  27171.000000   27171.000000
# mean                 1.643965  63722.979095       1.710390
# std                  0.754278  24745.063920       0.782493
# min                  1.000000      9.000000       1.000000
# 25%                  1.000000  51977.500000       1.000000
# 50%                  1.000000  67298.000000       2.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27171 entries, 9 to 99999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Artifact                5785 non-null   object
#  1   Category                27171 non-null  object
#  2   Eastern Resource        12139 non-null  object
#  3   Eastern Resource Tier   12139 non-null  float64
#  4   Environment             27171 non-null  object
#  5   Environment Tier        27171 non-null  int64
#  6   Koda                    3076 non-null   float64
#  7   Northern Resource       11996 non-null  object
#  8   Northern Resource Tier  11996 non-null  float64
#  9   Obelisk Piece           6946 non-null   object
#  10  Plot                    27171 non-null  int64
#  11  Sediment                27171 non-null  object
#  12  Sediment Tier           27171 non-null  int64
#  13  Southern Resource       11988 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Artifact"].value_counts(dropna=False)
# Out:
# None               21386
# Rugged Axe           264
# Ancient Coin         256
# Banana Peel          253
# Rugged Shovel        251
#                    ...
# Unknown Map           14
# Portal Piece           2
# Relic Book Page        2
# Red Obelisk            1
# Yellow Obelisk         1
# Name: Artifact, Length: 65, dtype: int64

# %%
df["Category"].value_counts(dropna=False)
# Out:
# Decay          5187
# Harsh          4931
# Spirit         4369
# Volcanic       4037
# Mineral        3283
# Growth         2906
# Psychedelic    2420
# Chaos            38
# Name: Category, dtype: int64

# %%
df["Eastern Resource"].value_counts(dropna=False)
# Out:
# None           15032
# Bonestone        805
# Luster           789
# Moldium          788
# Runa             784
#                ...
# Fragmentia        11
# Galactica          9
# Stonecrop          8
# Dimensional        8
# Entradium          7
# Name: Eastern Resource, Length: 75, dtype: int64

# %%
df["Eastern Resource Tier"].value_counts(dropna=False)
# Out:
# NaN    15032
# 1.0     6410
# 2.0     3717
# 3.0     2012
# Name: Eastern Resource Tier, dtype: int64

# %%
df["Environment"].value_counts(dropna=False)
# Out:
# Bog          1893
# Glacia       1769
# Steppes      1574
# Molten       1469
# Thornwood    1368
# Splinter     1337
# Sands        1209
# Biolume      1192
# Ruins        1129
# Wastes       1103
# Sulfuric     1061
# Mystic       1019
# Veldan        911
# Spires        865
# Crimson       864
# Mallow        827
# Plague        797
# Jungle        773
# Crystal       724
# Bone          722
# Sky           675
# Mycelium      660
# Obsidian      643
# Shadow        632
# Sludge        525
# Luster        502
# Botanical     454
# Acid          436
# Chaos          38
# Name: Environment, dtype: int64

# %%
df["Environment Tier"].value_counts(dropna=False)
# Out:
# 1    8206
# 2    6759
# 3    5511
# 4    4047
# 5    2648
# Name: Environment Tier, dtype: int64

# %%
df["Northern Resource"].value_counts(dropna=False)
# Out:
# None          15175
# Luster          801
# Psychosilk      786
# Kinsoul         771
# Moldium         767
#               ...
# Entradium        12
# Sporicite        11
# Fragmentia        8
# Lapidite          7
# Stonecrop         6
# Name: Northern Resource, Length: 75, dtype: int64

# %%
df["Northern Resource Tier"].value_counts(dropna=False)
# Out:
# NaN    15175
# 1.0     6308
# 2.0     3651
# 3.0     2037
# Name: Northern Resource Tier, dtype: int64

# %%
df["Obelisk Piece"].value_counts(dropna=False)
# Out:
# None          20225
# First Trip     6946
# Name: Obelisk Piece, dtype: int64

# %%
df["Sediment"].value_counts(dropna=False)
# Out:
# Rainbow Atmos       9793
# Infinite Expanse    8536
# Cosmic Dream        5005
# Chemical Goo        2885
# Biogenic Swamp       952
# Name: Sediment, dtype: int64

# %%
df["Sediment Tier"].value_counts(dropna=False)
# Out:
# 1    13392
# 2     8256
# 3     5523
# Name: Sediment Tier, dtype: int64

# %%
df["Southern Resource"].value_counts(dropna=False)
# Out:
# None           15183
# Lumileaf         780
# Bonestone        779
# Whisper          767
# Lunarian         766
#                ...
# Dimensional       12
# Tanglevine        12
# Fossica           12
# Lapidite          10
# Stonecrop         10
# Name: Southern Resource, Length: 75, dtype: int64

# %%
df["Southern Resource Tier"].value_counts(dropna=False)
# Out:
# NaN    15183
# 1.0     6233
# 2.0     3742
# 3.0     2013
# Name: Southern Resource Tier, dtype: int64

# %%
df["Western Resource"].value_counts(dropna=False)
# Out:
# None           15005
# Nether           802
# Psychosilk       790
# Lumileaf         785
# Moldium          782
#                ...
# Galactica         13
# Aurelian          12
# Lapidite          11
# Fragmentia        11
# Dimensional       10
# Name: Western Resource, Length: 75, dtype: int64

# %%
df["Western Resource Tier"].value_counts(dropna=False)
# Out:
# NaN    15005
# 1.0     6481
# 2.0     3645
# 3.0     2040
# Name: Western Resource Tier, dtype: int64

# %%
sns.pairplot(df, diag_kind='kde')

# %%
sns.boxplot(x='price_usd', y='Category', data=df, hue='Category')
# Out:
# <AxesSubplot: xlabel='price_usd', ylabel='Category'>

# %%
sns.boxplot(x='Eastern Resource Tier', y='price_usd', data=df, orient='v', hue='Eastern Resource Tier')
# Out:
# <AxesSubplot: xlabel='Eastern Resource Tier', ylabel='price_usd'>

# %%
sns.boxplot(x='Northern Resource Tier', y='price_usd', data=df, orient='v', hue='Northern Resource Tier')
# Out:
# <AxesSubplot: xlabel='Northern Resource Tier', ylabel='price_usd'>

# %%
sns.boxplot(x='Southern Resource Tier', y='price_usd', data=df, orient='v', hue='Southern Resource Tier')
# Out:
# <AxesSubplot: xlabel='Southern Resource Tier', ylabel='price_usd'>

# %%
sns.boxplot(x='Western Resource Tier', y='price_usd', data=df, orient='v', hue='Western Resource Tier')
# Out:
# <AxesSubplot: xlabel='Western Resource Tier', ylabel='price_usd'>

# %%
fig = plt.subplots(1, 1, figsize=(6, 10))
plt.subplot(111)
sns.boxplot(x='Environment Tier', y='price_usd', data=df, hue='Environment Tier')
# Out:
# <AxesSubplot: xlabel='Environment Tier', ylabel='price_usd'>

# %%
artifact_df = df[['Artifact', 'price_usd']]
temp = []
for i in artifact_df['Artifact']:
    if (i is None):
        temp.append('n')
    else:
        temp.append('y')
artifact_df['has_Artifact'] = temp

fig = plt.subplots(1, 1, figsize=(10, 5))
plt.subplot(111)
sns.boxplot(x='price_usd', y='has_Artifact', data=artifact_df, hue='has_Artifact')
# Out:
# /var/folders/x2/q5931tb11yq9yxz816qjmy7w0000gn/T/ipykernel_2150/2128000207.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artifact_df['has_Artifact'] = temp
# <AxesSubplot: xlabel='price_usd', ylabel='has_Artifact'>

# %%
koda_df = df[['Koda', 'price_usd']]
temp = []
for i in koda_df['Koda']:
    if (np.isnan(i)):
        temp.append('n')
    else:
        temp.append('y')
koda_df['has_Koda'] = temp

fig = plt.subplots(1, 1, figsize=(10, 5))
plt.subplot(111)
sns.boxplot(x='price_usd', y='has_Koda', data=koda_df, hue='has_Koda')
# Out:
# /var/folders/x2/q5931tb11yq9yxz816qjmy7w0000gn/T/ipykernel_2150/2430379990.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   koda_df['has_Koda'] = temp
# <AxesSubplot: xlabel='price_usd', ylabel='has_Koda'>

# %%
obelisk_df = df[['Obelisk Piece', 'price_usd']]
temp = []
for i in obelisk_df['Obelisk Piece']:
    if (i is None):
        temp.append('n')
    else:
        temp.append('y')
obelisk_df['has_Obelisk_Piece'] = temp

fig = plt.subplots(1, 1, figsize=(10, 5))
plt.subplot(111)
sns.boxplot(x='price_usd', y='has_Obelisk_Piece', data=obelisk_df, hue='has_Obelisk_Piece')
# Out:
# /var/folders/x2/q5931tb11yq9yxz816qjmy7w0000gn/T/ipykernel_2150/3883190008.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obelisk_df['has_Obelisk_Piece'] = temp
# <AxesSubplot: xlabel='price_usd', ylabel='has_Obelisk_Piece'>

# %%
sns.scatterplot(x="Koda", y="price_usd", data=df, s=80)
# Out:
# <AxesSubplot: xlabel='Koda', ylabel='price_usd'>

# %%
sns.scatterplot(x="token_ids", y="price_usd", data=df, s=80)
# Out:
# <AxesSubplot: xlabel='token_ids', ylabel='price_usd'>

# %%
corrmat = df.corr()
sns.heatmap(corrmat, vmin=-1, vmax=1, cbar=True, annot=True, fmt='.2f', cmap="Spectral_r")
# Out:
# <AxesSubplot: >
