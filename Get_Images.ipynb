# %%
import pandas as pd
import json

# %%
data = pd.read_csv("preprocessed_dataset/new_trade_df.csv")
trades_df = pd.DataFrame(data)
nft_df_1 = pd.read_csv("preprocessed_dataset/ntf_df1.csv")
nft_df_2 = pd.read_csv("preprocessed_dataset/ntf_df2.csv")
nft_df_3 = pd.read_csv("preprocessed_dataset/ntf_df3.csv")
nft_df_4 = pd.read_csv("preprocessed_dataset/ntf_df4.csv")
nft_df_5 = pd.read_csv("preprocessed_dataset/ntf_df5.csv")
nft_df = pd.concat([nft_df_1, nft_df_2, nft_df_3, nft_df_4, nft_df_5])
nft_df=nft_df.rename(columns={"token_id":"token_ids"})
trades_df = trades_df[["token_ids","block_timestamp","price_usd"]]
temp = []
for i in nft_df['metadata']:
    js = json.loads(json.dumps(eval(i)))
    temp.append(js['image'])
nft_df['image'] = temp
nft_df = nft_df[['token_ids', 'image', 'Artifact', 'Category',
    'Eastern Resource', 'Eastern Resource Tier', 'Environment',
    'Environment Tier', 'Koda', 'Northern Resource',
    'Northern Resource Tier', 'Obelisk Piece', 'Plot', 'Sediment',
    'Sediment Tier', 'Southern Resource', 'Southern Resource Tier',
    'Western Resource', 'Western Resource Tier']]
df = nft_df.merge(trades_df, on='token_ids', how='left')
df
# Out:
# /var/folders/x2/q5931tb11yq9yxz816qjmy7w0000gn/T/ipykernel_6687/494433997.py:4: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   nft_df_2 = pd.read_csv("preprocessed_dataset/ntf_df2.csv")
#         token_ids                                              image  \
# 0               0  https://assets.otherside.xyz/otherdeeds/98de81...
# 1               1  https://assets.otherside.xyz/otherdeeds/871079...
# 2               2  https://assets.otherside.xyz/otherdeeds/96ad82...
# 3               3  https://assets.otherside.xyz/otherdeeds/54abf7...
# 4               4  https://assets.otherside.xyz/otherdeeds/88e0c4...
# ...           ...                                                ...
# 108944      99996  https://assets.otherside.xyz/otherdeeds/1269b0...
# 108945      99996  https://assets.otherside.xyz/otherdeeds/1269b0...
# 108946      99997  https://assets.otherside.xyz/otherdeeds/918350...
# 108947      99998  https://assets.otherside.xyz/otherdeeds/4fc256...
# 108948      99999  https://assets.otherside.xyz/otherdeeds/6f8a74...
#
#               Artifact     Category Eastern Resource  Eastern Resource Tier  \
# 0                  NaN       Spirit          Whisper                    3.0
# 1                  NaN     Volcanic              NaN                    NaN
# 2                  NaN       Spirit        Bonestone                    2.0
# 3                  NaN        Harsh        Spikeweed                    3.0
# 4       Forged Pickaxe        Decay         Lunarian                    1.0
# ...                ...          ...              ...                    ...
# 108944             NaN        Harsh              NaN                    NaN
# 108945             NaN        Harsh              NaN                    NaN
# 108946             NaN  Psychedelic       Psychosilk                    1.0
# 108947             NaN  Psychedelic        Spikeweed                    1.0
# 108948   Rugged Hammer      Mineral              NaN                    NaN
#
#        Environment  Environment Tier    Koda Northern Resource  ...  \
# 0          Steppes                 4  9068.0           Moldium  ...
# 1         Obsidian                 1     NaN           Abyssia  ...
# 2            Sands                 1     NaN          Lumileaf  ...
# 3         Splinter                 4     NaN               NaN  ...
# 4            Ruins                 1     NaN           Moldium  ...
# ...            ...               ...     ...               ...  ...
# 108944    Splinter                 1     NaN               NaN  ...
# 108945    Splinter                 1     NaN               NaN  ...
# 108946      Mallow                 3     NaN          Lumileaf  ...
# 108947      Sludge                 2     NaN               NaN  ...
# 108948     Biolume                 4     NaN          Oblivion  ...
#
#         Obelisk Piece   Plot        Sediment Sediment Tier  Southern Resource  \
# 0          First Trip      0  Biogenic Swamp             1           Lumileaf
# 1                 NaN      1  Biogenic Swamp             2                NaN
# 2          First Trip      2  Biogenic Swamp             3               Runa
# 3          First Trip      3  Biogenic Swamp             2            Whisper
# 4                 NaN      4  Biogenic Swamp             3                NaN
# ...               ...    ...             ...           ...                ...
# 108944            NaN  99996    Cosmic Dream             1           Lunarian
# 108945            NaN  99996    Cosmic Dream             1           Lunarian
# 108946            NaN  99997    Cosmic Dream             1               Runa
# 108947            NaN  99998    Cosmic Dream             1                NaN
# 108948     First Trip  99999    Cosmic Dream             1                NaN
#
#        Southern Resource Tier  Western Resource Western Resource Tier  \
# 0                         3.0               NaN                   NaN
# 1                         NaN         Brimstone                   3.0
# 2                         1.0            Luster                   1.0
# 3                         3.0               NaN                   NaN
# 4                         NaN          Lunarian                   1.0
# ...                       ...               ...                   ...
# 108944                    3.0        Steppesalt                   2.0
# 108945                    3.0        Steppesalt                   2.0
# 108946                    3.0         Bonestone                   1.0
# 108947                    NaN          Lunarian                   3.0
# 108948                    NaN               NaN                   NaN
#
#         block_timestamp     price_usd
# 0                   NaN           NaN
# 1                   NaN           NaN
# 2                   NaN           NaN
# 3                   NaN           NaN
# 4                   NaN           NaN
# ...                 ...           ...
# 108944       2022-07-07   3561.591446
# 108945       2022-05-01  28141.824015
# 108946              NaN           NaN
# 108947       2022-05-01  19116.231742
# 108948       2022-05-02  22620.911972
#
# [108949 rows x 21 columns]

# %%
df.to_csv("with_images.csv")
