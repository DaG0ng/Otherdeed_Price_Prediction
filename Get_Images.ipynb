# %%
import pandas as pd
import json

# %%
data = pd.read_csv("preprocessed_dataset/new_trade_df.csv")
trades_df = pd.DataFrame(data)
nft_df_1 = pd.read_csv("preprocessed_dataset/ntf_df1.csv")
nft_df_2 = pd.read_csv("preprocessed_dataset/ntf_df2.csv")
nft_df_3 = pd.read_csv("preprocessed_dataset/ntf_df3.csv")
nft_df_4 = pd.read_csv("preprocessed_dataset/ntf_df4.csv")
nft_df_5 = pd.read_csv("preprocessed_dataset/ntf_df5.csv")
nft_df = pd.concat([nft_df_1, nft_df_2, nft_df_3, nft_df_4, nft_df_5])
nft_df=nft_df.rename(columns={"token_id":"token_ids"})
trades_df = trades_df[["token_ids","block_timestamp","price_usd"]]
temp = []
for i in nft_df['metadata']:
    js = json.loads(json.dumps(eval(i)))
    temp.append(js['image'])
nft_df['image'] = temp
nft_df = nft_df[['token_ids', 'image', 'Artifact', 'Category',
    'Eastern Resource', 'Eastern Resource Tier', 'Environment',
    'Environment Tier', 'Koda', 'Northern Resource',
    'Northern Resource Tier', 'Obelisk Piece', 'Plot', 'Sediment',
    'Sediment Tier', 'Southern Resource', 'Southern Resource Tier',
    'Western Resource', 'Western Resource Tier']]
df = nft_df.merge(trades_df, on='token_ids', how='left')
df = df.dropna(subset=["price_usd"])
df = df.groupby("token_ids").first()
df
# Out:
# /var/folders/x2/q5931tb11yq9yxz816qjmy7w0000gn/T/ipykernel_5561/639369948.py:4: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   nft_df_2 = pd.read_csv("preprocessed_dataset/ntf_df2.csv")
#                                                        image       Artifact  \
# token_ids
# 9          https://assets.otherside.xyz/otherdeeds/b13521...           None
# 10         https://assets.otherside.xyz/otherdeeds/ad21c2...           None
# 12         https://assets.otherside.xyz/otherdeeds/f0d8f9...           None
# 16         https://assets.otherside.xyz/otherdeeds/fe4ecc...           None
# 17         https://assets.otherside.xyz/otherdeeds/b9ecb5...           None
# ...                                                      ...            ...
# 99990      https://assets.otherside.xyz/otherdeeds/5e819b...           None
# 99994      https://assets.otherside.xyz/otherdeeds/d7d381...           None
# 99996      https://assets.otherside.xyz/otherdeeds/1269b0...           None
# 99998      https://assets.otherside.xyz/otherdeeds/4fc256...           None
# 99999      https://assets.otherside.xyz/otherdeeds/6f8a74...  Rugged Hammer
#
#               Category Eastern Resource  Eastern Resource Tier Environment  \
# token_ids
# 9                Decay           Nether                    2.0   Thornwood
# 10               Decay             None                    NaN       Ruins
# 12               Decay             None                    NaN      Plague
# 16               Harsh          Whisper                    3.0        Bone
# 17               Decay             None                    NaN         Bog
# ...                ...              ...                    ...         ...
# 99990           Spirit       Psychosilk                    2.0     Steppes
# 99994          Mineral             None                    NaN      Spires
# 99996            Harsh             None                    NaN    Splinter
# 99998      Psychedelic        Spikeweed                    1.0      Sludge
# 99999          Mineral             None                    NaN     Biolume
#
#            Environment Tier  Koda Northern Resource  Northern Resource Tier  \
# token_ids
# 9                         2   NaN        Psychosilk                     2.0
# 10                        1   NaN            Chroma                     1.0
# 12                        3   NaN              None                     NaN
# 16                        3   NaN              Runa                     3.0
# 17                        2   NaN              None                     NaN
# ...                     ...   ...               ...                     ...
# 99990                     2   NaN              None                     NaN
# 99994                     4   NaN              Runa                     1.0
# 99996                     1   NaN              None                     NaN
# 99998                     2   NaN              None                     NaN
# 99999                     4   NaN          Oblivion                     1.0
#
#           Obelisk Piece   Plot        Sediment  Sediment Tier  \
# token_ids
# 9                  None      9  Biogenic Swamp              1
# 10                 None     10  Biogenic Swamp              3
# 12                 None     12  Biogenic Swamp              2
# 16           First Trip     16  Biogenic Swamp              2
# 17           First Trip     17  Biogenic Swamp              1
# ...                 ...    ...             ...            ...
# 99990              None  99990    Cosmic Dream              3
# 99994              None  99994    Cosmic Dream              2
# 99996              None  99996    Cosmic Dream              1
# 99998              None  99998    Cosmic Dream              1
# 99999        First Trip  99999    Cosmic Dream              1
#
#           Southern Resource  Southern Resource Tier Western Resource  \
# token_ids
# 9                      None                     NaN             None
# 10                Bonestone                     1.0         Oblivion
# 12                     None                     NaN             None
# 16                     None                     NaN             None
# 17                Bonestone                     3.0             None
# ...                     ...                     ...              ...
# 99990                  None                     NaN          Whisper
# 99994             Petrified                     1.0         Lunarian
# 99996              Lunarian                     3.0       Steppesalt
# 99998                  None                     NaN         Lunarian
# 99999                  None                     NaN             None
#
#            Western Resource Tier block_timestamp      price_usd
# token_ids
# 9                            NaN      2022-05-02  848284.198934
# 10                           2.0      2022-05-02  706903.499112
# 12                           NaN      2022-09-08  455201.191705
# 16                           NaN      2022-09-08  407886.372496
# 17                           NaN      2022-09-08  228416.368598
# ...                          ...             ...            ...
# 99990                        1.0      2022-05-01   13490.597830
# 99994                        2.0      2022-06-13    2625.397572
# 99996                        2.0      2022-07-12    3892.762727
# 99998                        3.0      2022-05-01   19116.231742
# 99999                        NaN      2022-05-02   22620.911972
#
# [27171 rows x 20 columns]

# %%
df.to_csv("with_images.csv")
